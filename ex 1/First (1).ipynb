# %%
import pandas as pd
file_path = 'sales-of-shampoo-over-a-three-ye.csv'
data = pd.read_csv(file_path)
print(data)
data.columns = ['Month', 'Sales of shampoo over a three year period']
data['Month'] = pd.to_datetime(data['Month'], format='%d-%b', errors='coerce')
data = data.dropna(subset=['Month'])
data = data.sort_values('Month')
data = data.reset_index(drop=True)
print("Cleaned Data:")
print(data.head())
data['Sales of shampoo over a three year period'] = data['Sales of shampoo over a three year period'].fillna(data['Sales of shampoo over a three year period'].mean())
data.to_csv('cleaned_sales_data.csv', index=False)
print("Data cleaning and preprocessing completed.")
plt.figure(figsize=(10, 6))
plt.plot(data['Month'], data['Sales of shampoo over a three year period'], marker='o', linestyle='-', color='b', label='Sales')
plt.title('Sales of Shampoo Over Time', fontsize=16)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Sales', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xticks(rotation=45, fontsize=10)
plt.tight_layout()
plt.show()
# Out:
#     Month  Sales of shampoo over a three year period
# 0   1-Jan                                      266.0
# 1   1-Feb                                      145.9
# 2   1-Mar                                      183.1
# 3   1-Apr                                      119.3
# 4   1-May                                      180.3
# 5   1-Jun                                      168.5
# 6   1-Jul                                      231.8
# 7   1-Aug                                      224.5
# 8   1-Sep                                      192.8
# 9   1-Oct                                      122.9
# 10  1-Nov                                      336.5
# 11  1-Dec                                      185.9
# 12  2-Jan                                      194.3
# 13  2-Feb                                      149.5
# 14  2-Mar                                      210.1
# 15  2-Apr                                      273.3
# 16  2-May                                      191.4
# ...
